# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/kusha/OneDrive/Desktop/Capstone Project/Capstone Project/BMW_Sales_2020_2025.csv")

# %%
#  Data overview
df
# Out:
#       Year Month     Model       Type     Power         Region Country  \
# 0     2020   Jan  3 Series      Sedan    Diesel         Europe   Italy
# 1     2020   Jan  3 Series      Sedan    Petrol            USA     USA
# 2     2020   Jan  3 Series      Sedan    Hybrid          China   China
# 3     2020   Jan  3 Series      Sedan    Hybrid  Rest_of_World   Japan
# 4     2020   Jan  5 Series      Sedan    Petrol         Europe  France
# ...    ...   ...       ...        ...       ...            ...     ...
# 5755  2025   Dec        i3  Hatchback  Electric  Rest_of_World  Brazil
# 5756  2025   Dec        X6        SUV    Diesel         Europe      UK
# 5757  2025   Dec        X6        SUV  Electric            USA     USA
# 5758  2025   Dec        X6        SUV  Electric          China   China
# 5759  2025   Dec        X6        SUV  Electric  Rest_of_World   Japan
#
#       Units_Sold  Avg_Price_USD  Revenue_USD      Cost_USD   Profit_USD  \
# ...

# %%
df.head()           # View the first 5 rows of the dataset.
# Out:
#    Year Month     Model   Type   Power         Region Country  Units_Sold  \
# 0  2020   Jan  3 Series  Sedan  Diesel         Europe   Italy        1111
# 1  2020   Jan  3 Series  Sedan  Petrol            USA     USA        1066
# 2  2020   Jan  3 Series  Sedan  Hybrid          China   China        1429
# 3  2020   Jan  3 Series  Sedan  Hybrid  Rest_of_World   Japan         241
# 4  2020   Jan  5 Series  Sedan  Petrol         Europe  France        1141
#
#    Avg_Price_USD  Revenue_USD      Cost_USD   Profit_USD  Profit_Margin  \
# 0        35690.0   39651590.0  2.620222e+07  13449371.78          33.92
# 1        75004.0   79954264.0           NaN  18198744.42          22.76
# 2       106934.0  152808686.0  1.018600e+08  50948676.53          33.34
# 3        78914.0   19018274.0  1.597889e+07   3039387.93          15.98
# 4        45835.0   52297735.0  4.007558e+07  12222153.70          23.37
#
#    Gross_Margin  Operating_Expenses_USD  Net_Profit_USD    ROI  EBITDA_Margin
# ...

# %%
df.tail()           # View the last 5 rows of the dataset.
# Out:
#       Year Month Model       Type     Power         Region Country  \
# 5755  2025   Dec    i3  Hatchback  Electric  Rest_of_World  Brazil
# 5756  2025   Dec    X6        SUV    Diesel         Europe      UK
# 5757  2025   Dec    X6        SUV  Electric            USA     USA
# 5758  2025   Dec    X6        SUV  Electric          China   China
# 5759  2025   Dec    X6        SUV  Electric  Rest_of_World   Japan
#
#       Units_Sold  Avg_Price_USD  Revenue_USD      Cost_USD   Profit_USD  \
# 5755         822        49241.0   40476102.0  3.317342e+07   7302680.77
# 5756        2462        60959.0  150081058.0  1.275409e+08  22540150.45
# 5757         797       102701.0   81852697.0  6.800516e+07  13847542.00
# 5758        1388        99739.0  138437732.0  1.015569e+08  36880803.57
# 5759        2040        80220.0  163648800.0  1.078106e+08  55838229.06
#
#       Profit_Margin  Gross_Margin  Operating_Expenses_USD  Net_Profit_USD  \
# ...

# %%
df.info()         # Get a concise summary of the DataFrame.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5760 entries, 0 to 5759
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    5760 non-null   int64
#  1   Month                   5760 non-null   object
#  2   Model                   5760 non-null   object
#  3   Type                    5760 non-null   object
#  4   Power                   5760 non-null   object
#  5   Region                  5760 non-null   object
#  6   Country                 5760 non-null   object
#  7   Units_Sold              5760 non-null   int64
#  8   Avg_Price_USD           5477 non-null   float64
#  9   Revenue_USD             5434 non-null   float64
#  10  Cost_USD                5477 non-null   float64
#  11  Profit_USD              5471 non-null   float64
#  12  Profit_Margin           5760 non-null   float64
#  13  Gross_Margin            5760 non-null   float64
# ...

# %%
df.describe()     # Generate descriptive statistics.
# Out:
#               Year   Units_Sold  Avg_Price_USD   Revenue_USD      Cost_USD  \
# count  5760.000000  5760.000000    5477.000000  5.434000e+03  5.477000e+03
# mean   2022.500000  1229.528993   77404.976447  9.501996e+07  7.157151e+07
# std       1.707973   591.612366   24439.143831  5.666211e+07  4.296839e+07
# min    2020.000000   201.000000   35012.000000  8.389730e+06  6.210313e+06
# 25%    2021.000000   729.000000   56298.000000  4.924266e+07  3.721286e+07
# 50%    2022.500000  1215.000000   77220.000000  8.383573e+07  6.345579e+07
# 75%    2024.000000  1716.000000   98620.000000  1.309715e+08  9.845675e+07
# max    2025.000000  2500.000000  119995.000000  2.882601e+08  2.305263e+08
#
#          Profit_USD  Profit_Margin  Gross_Margin  Operating_Expenses_USD  \
# count  5.471000e+03    5760.000000   5760.000000            5.434000e+03
# mean   2.357012e+07      24.798679     34.969679            1.204648e+07
# ...

# %%
print("Columns in the dataset:",df.columns)  # List all column names in the DataFrame.
# Out:
# Columns in the dataset: Index(['Year', 'Month', 'Model', 'Type', 'Power', 'Region', 'Country',
#        'Units_Sold', 'Avg_Price_USD', 'Revenue_USD', 'Cost_USD', 'Profit_USD',
#        'Profit_Margin', 'Gross_Margin', 'Operating_Expenses_USD',
#        'Net_Profit_USD', 'ROI', 'EBITDA_Margin'],
#       dtype='object')

# %%
print("Shape of the dataset:",df.shape)    # Get the number of rows and columns in the DataFrame.
# Out:
# Shape of the dataset: (5760, 18)

# %%
df_original = df.copy()

# %%
#  Data Cleaning

# %%
df.isnull().sum()   # Check for missing values in each column.
# Out:
# Year                        0
# Month                       0
# Model                       0
# Type                        0
# Power                       0
# Region                      0
# Country                     0
# Units_Sold                  0
# Avg_Price_USD             283
# Revenue_USD               326
# Cost_USD                  283
# Profit_USD                289
# Profit_Margin               0
# Gross_Margin                0
# Operating_Expenses_USD    326
# Net_Profit_USD            599
# ROI                       852
# EBITDA_Margin               0
# dtype: int64

# %%
df.duplicated()          # Check for duplicate rows in the DataFrame.
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5755    False
# 5756    False
# 5757    False
# 5758    False
# 5759    False
# Length: 5760, dtype: bool

# %%
df.drop_duplicates(inplace=True)  # Remove duplicate rows from the DataFrame.

# %%
df
# Out:
#       Year Month     Model       Type     Power         Region Country  \
# 0     2020   Jan  3 Series      Sedan    Diesel         Europe   Italy
# 1     2020   Jan  3 Series      Sedan    Petrol            USA     USA
# 2     2020   Jan  3 Series      Sedan    Hybrid          China   China
# 3     2020   Jan  3 Series      Sedan    Hybrid  Rest_of_World   Japan
# 4     2020   Jan  5 Series      Sedan    Petrol         Europe  France
# ...    ...   ...       ...        ...       ...            ...     ...
# 5755  2025   Dec        i3  Hatchback  Electric  Rest_of_World  Brazil
# 5756  2025   Dec        X6        SUV    Diesel         Europe      UK
# 5757  2025   Dec        X6        SUV  Electric            USA     USA
# 5758  2025   Dec        X6        SUV  Electric          China   China
# 5759  2025   Dec        X6        SUV  Electric  Rest_of_World   Japan
#
#       Units_Sold  Avg_Price_USD  Revenue_USD      Cost_USD   Profit_USD  \
# ...

# %%
df_clean = df.copy()
df_clean["Revenue_USD"].fillna(df_clean["Revenue_USD"].median(), inplace=True)
df_clean["Cost_USD"].fillna(df_clean["Cost_USD"].median(), inplace=True)
df
# Out:
#       Year Month     Model       Type     Power         Region Country  \
# 0     2020   Jan  3 Series      Sedan    Diesel         Europe   Italy
# 1     2020   Jan  3 Series      Sedan    Petrol            USA     USA
# 2     2020   Jan  3 Series      Sedan    Hybrid          China   China
# 3     2020   Jan  3 Series      Sedan    Hybrid  Rest_of_World   Japan
# 4     2020   Jan  5 Series      Sedan    Petrol         Europe  France
# ...    ...   ...       ...        ...       ...            ...     ...
# 5755  2025   Dec        i3  Hatchback  Electric  Rest_of_World  Brazil
# 5756  2025   Dec        X6        SUV    Diesel         Europe      UK
# 5757  2025   Dec        X6        SUV  Electric            USA     USA
# 5758  2025   Dec        X6        SUV  Electric          China   China
# 5759  2025   Dec        X6        SUV  Electric  Rest_of_World   Japan
#
#       Units_Sold  Avg_Price_USD  Revenue_USD      Cost_USD   Profit_USD  \
# ...

# %%
import pandas as pd
import numpy as np
import random

df = pd.read_csv("C:/Users/kusha/OneDrive/Desktop/Capstone Project/Capstone Project/BMW_Sales_2020_2025.csv")

# Numeric columns: replace NaN with a random number within column range
num_cols = ["Units_Sold", "Avg_Price_USD", "Revenue_USD", "Cost_USD", "Profit_USD"]
for col in num_cols:
    df.replace({col: {np.nan: random.randint(int(df[col].min()), int(df[col].max()))}}, inplace=True)

# Categorical columns: replace NaN with a random existing value
cat_cols = ["Power", "Region", "Country"]
for col in cat_cols:
    df.replace({col: {np.nan: random.choice(df[col].dropna())}}, inplace=True)

df.to_csv("BMW_Sales_Filled_Replace.csv", index=False)

# %%
df
# Out:
#       Year Month     Model       Type     Power         Region Country  \
# 0     2020   Jan  3 Series      Sedan    Diesel         Europe   Italy
# 1     2020   Jan  3 Series      Sedan    Petrol            USA     USA
# 2     2020   Jan  3 Series      Sedan    Hybrid          China   China
# 3     2020   Jan  3 Series      Sedan    Hybrid  Rest_of_World   Japan
# 4     2020   Jan  5 Series      Sedan    Petrol         Europe  France
# ...    ...   ...       ...        ...       ...            ...     ...
# 5755  2025   Dec        i3  Hatchback  Electric  Rest_of_World  Brazil
# 5756  2025   Dec        X6        SUV    Diesel         Europe      UK
# 5757  2025   Dec        X6        SUV  Electric            USA     USA
# 5758  2025   Dec        X6        SUV  Electric          China   China
# 5759  2025   Dec        X6        SUV  Electric  Rest_of_World   Japan
#
#       Units_Sold  Avg_Price_USD  Revenue_USD      Cost_USD   Profit_USD  \
# ...

# %%
# Data Exploration

# %%
df['Power'].value_counts()   # Counts unique values.
# Out:
# Power
# Electric    2277
# Petrol      1744
# Diesel       875
# Hybrid       864
# Name: count, dtype: int64

# %%
df['Model'].unique()      # Lists unique values in the 'Model' column.
# Out:
# array(['3 Series', '5 Series', '7 Series', 'X1', 'X3', 'X5', 'X7', 'Z4',
#        'i4', 'iX', 'i7', 'M3', 'M5', 'M8', 'iX3', '2 Series', '4 Series',
#        '8 Series', 'i3', 'X6'], dtype=object)

# %%
df['Model'].nunique()     # Counts unique models in the 'Model' column.
# Out:
# 20

# %%
df
# Out:
#       Year Month     Model       Type     Power         Region Country  \
# 0     2020   Jan  3 Series      Sedan    Diesel         Europe   Italy
# 1     2020   Jan  3 Series      Sedan    Petrol            USA     USA
# 2     2020   Jan  3 Series      Sedan    Hybrid          China   China
# 3     2020   Jan  3 Series      Sedan    Hybrid  Rest_of_World   Japan
# 4     2020   Jan  5 Series      Sedan    Petrol         Europe  France
# ...    ...   ...       ...        ...       ...            ...     ...
# 5755  2025   Dec        i3  Hatchback  Electric  Rest_of_World  Brazil
# 5756  2025   Dec        X6        SUV    Diesel         Europe      UK
# 5757  2025   Dec        X6        SUV  Electric            USA     USA
# 5758  2025   Dec        X6        SUV  Electric          China   China
# 5759  2025   Dec        X6        SUV  Electric  Rest_of_World   Japan
#
#       Units_Sold  Avg_Price_USD  Revenue_USD      Cost_USD   Profit_USD  \
# ...

# %%
df.groupby (['Region' , 'Country'])['Units_Sold'].mean()
# Out:
# Region         Country
# China          China           1217.795139
# Europe         France          1184.759322
#                Germany         1191.035587
#                Italy           1226.339744
#                Spain           1251.429630
#                UK              1252.294326
# Rest_of_World  Australia       1268.626582
#                Brazil          1234.610487
#                India           1186.088968
#                Japan           1299.886986
#                South Africa    1223.080986
# USA            USA             1236.031944
# Name: Units_Sold, dtype: float64

# %%
df.groupby('Country')['Units_Sold'].mean()
# Out:
# Country
# Australia       1268.626582
# Brazil          1234.610487
# China           1217.795139
# France          1184.759322
# Germany         1191.035587
# India           1186.088968
# Italy           1226.339744
# Japan           1299.886986
# South Africa    1223.080986
# Spain           1251.429630
# UK              1252.294326
# USA             1236.031944
# Name: Units_Sold, dtype: float64

# %%
df.groupby (['Region' , 'Country' , 'Type'])['Units_Sold'].mean()
# Out:
# Region         Country       Type
# China          China         Convertible    1138.013889
#                              Coupe          1244.979167
#                              Hatchback      1321.604167
#                              SUV            1194.081349
#                              Sedan          1206.032407
# Europe         France        Convertible    1201.833333
#                              Coupe          1165.343284
#                              Hatchback      1188.870968
#                              SUV            1163.500000
#                              Sedan          1218.573034
#                Germany       Convertible    1072.750000
#                              Coupe          1156.384615
#                              Hatchback      1203.555556
#                              SUV            1206.626263
#                              Sedan          1221.621622
#                Italy         Convertible    1210.777778
# ...

# %%
df.groupby(['Model','Type','Power','Region'])[['Units_Sold', 'Cost_USD']].mean()
# Out:
#                                             Units_Sold      Cost_USD
# Model    Type      Power    Region
# 2 Series Hatchback Diesel   China          1095.153846  7.753450e+07
#                             Europe         1213.666667  6.565864e+07
#                             Rest_of_World  1121.562500  6.330104e+07
#                             USA            1222.782609  8.538030e+07
#                    Electric China          1141.315789  6.006713e+07
# ...                                                ...           ...
# iX       SUV       Electric USA            1263.819444  8.859279e+07
# iX3      SUV       Electric China          1165.888889  7.049692e+07
#                             Europe         1123.666667  6.722961e+07
#                             Rest_of_World  1267.930556  8.643712e+07
#                             USA            1246.375000  8.010689e+07
#
# [224 rows x 2 columns]
