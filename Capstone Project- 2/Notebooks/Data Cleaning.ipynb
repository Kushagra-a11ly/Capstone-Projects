# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("C:/Users/kusha/OneDrive/Desktop/Capstone Project/Capstone Project 2/retail_sales_dataset.xlsx")
print(df)
# Out:
#      Order_ID        Date Product_ID Product_Name     Category Region  \
# 0    ORD00000  2023-04-13    CLO_535        Shirt     Clothing  South
# 1    ORD00001  2023-05-02    FUR_566        Chair    Furniture   East
# 2    ORD00002  2023-06-01    CLO_230        Jeans     Clothing   East
# 3    ORD00003  2023-10-04    FUR_260        Table    Furniture  South
# 4    ORD00004  2023-06-19    FUR_575         Sofa    Furniture  North
# ..        ...         ...        ...          ...          ...    ...
# 995  ORD00995  2023-03-11    CLO_265        Shoes     Clothing   West
# 996  ORD00996  2023-12-15    CLO_683        Shirt     Clothing  South
# 997  ORD00997  2023-06-15    FUR_473        Table    Furniture  North
# 998  ORD00998  2023-11-06    ELE_457       Laptop  Electronics   West
# 999  ORD00999  2023-11-11    ELE_936       Laptop  Electronics  South
#
#             City Customer_ID  Gender  Age  Units_Sold  Unit_Price  Discount  \
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID        0
# Date            0
# Product_ID      0
# Product_Name    0
# Category        0
# Region          0
# City            0
# Customer_ID     0
# Gender          0
# Age             0
# Units_Sold      0
# Unit_Price      0
# Discount        0
# Revenue         0
# Cost            0
# Profit          0
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#      Order_ID        Date Product_ID Product_Name     Category Region  \
# 0    ORD00000  2023-04-13    CLO_535        Shirt     Clothing  South
# 1    ORD00001  2023-05-02    FUR_566        Chair    Furniture   East
# 2    ORD00002  2023-06-01    CLO_230        Jeans     Clothing   East
# 3    ORD00003  2023-10-04    FUR_260        Table    Furniture  South
# 4    ORD00004  2023-06-19    FUR_575         Sofa    Furniture  North
# ..        ...         ...        ...          ...          ...    ...
# 995  ORD00995  2023-03-11    CLO_265        Shoes     Clothing   West
# 996  ORD00996  2023-12-15    CLO_683        Shirt     Clothing  South
# 997  ORD00997  2023-06-15    FUR_473        Table    Furniture  North
# 998  ORD00998  2023-11-06    ELE_457       Laptop  Electronics   West
# 999  ORD00999  2023-11-11    ELE_936       Laptop  Electronics  South
#
#             City Customer_ID  Gender  Age  Units_Sold  Unit_Price  Discount  \
# ...

# %%
df.isnull()
# Out:
#      Order_ID   Date  Product_ID  Product_Name  Category  Region   City  \
# 0       False  False       False         False     False   False  False
# 1       False  False       False         False     False   False  False
# 2       False  False       False         False     False   False  False
# 3       False  False       False         False     False   False  False
# 4       False  False       False         False     False   False  False
# ..        ...    ...         ...           ...       ...     ...    ...
# 995     False  False       False         False     False   False  False
# 996     False  False       False         False     False   False  False
# 997     False  False       False         False     False   False  False
# 998     False  False       False         False     False   False  False
# 999     False  False       False         False     False   False  False
#
#      Customer_ID  Gender    Age  Units_Sold  Unit_Price  Discount  Revenue  \
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      Order_ID        Date Product_ID Product_Name     Category Region  \
# 0    ORD00000  2023-04-13    CLO_535        Shirt     Clothing  South
# 1    ORD00001  2023-05-02    FUR_566        Chair    Furniture   East
# 2    ORD00002  2023-06-01    CLO_230        Jeans     Clothing   East
# 3    ORD00003  2023-10-04    FUR_260        Table    Furniture  South
# 4    ORD00004  2023-06-19    FUR_575         Sofa    Furniture  North
# ..        ...         ...        ...          ...          ...    ...
# 995  ORD00995  2023-03-11    CLO_265        Shoes     Clothing   West
# 996  ORD00996  2023-12-15    CLO_683        Shirt     Clothing  South
# 997  ORD00997  2023-06-15    FUR_473        Table    Furniture  North
# 998  ORD00998  2023-11-06    ELE_457       Laptop  Electronics   West
# 999  ORD00999  2023-11-11    ELE_936       Laptop  Electronics  South
#
#             City Customer_ID  Gender  Age  Units_Sold  Unit_Price  Discount  \
# ...

# %%
df
# Out:
#      Order_ID        Date Product_ID Product_Name     Category Region  \
# 0    ORD00000  2023-04-13    CLO_535        Shirt     Clothing  South
# 1    ORD00001  2023-05-02    FUR_566        Chair    Furniture   East
# 2    ORD00002  2023-06-01    CLO_230        Jeans     Clothing   East
# 3    ORD00003  2023-10-04    FUR_260        Table    Furniture  South
# 4    ORD00004  2023-06-19    FUR_575         Sofa    Furniture  North
# ..        ...         ...        ...          ...          ...    ...
# 995  ORD00995  2023-03-11    CLO_265        Shoes     Clothing   West
# 996  ORD00996  2023-12-15    CLO_683        Shirt     Clothing  South
# 997  ORD00997  2023-06-15    FUR_473        Table    Furniture  North
# 998  ORD00998  2023-11-06    ELE_457       Laptop  Electronics   West
# 999  ORD00999  2023-11-11    ELE_936       Laptop  Electronics  South
#
#             City Customer_ID  Gender  Age  Units_Sold  Unit_Price  Discount  \
# ...

# %%
df.rename(columns={'Revenue':'Earnings'},inplace = True)
df
# Out:
#      Order_ID        Date Product_ID Product_Name     Category Region  \
# 0    ORD00000  2023-04-13    CLO_535        Shirt     Clothing  South
# 1    ORD00001  2023-05-02    FUR_566        Chair    Furniture   East
# 2    ORD00002  2023-06-01    CLO_230        Jeans     Clothing   East
# 3    ORD00003  2023-10-04    FUR_260        Table    Furniture  South
# 4    ORD00004  2023-06-19    FUR_575         Sofa    Furniture  North
# ..        ...         ...        ...          ...          ...    ...
# 995  ORD00995  2023-03-11    CLO_265        Shoes     Clothing   West
# 996  ORD00996  2023-12-15    CLO_683        Shirt     Clothing  South
# 997  ORD00997  2023-06-15    FUR_473        Table    Furniture  North
# 998  ORD00998  2023-11-06    ELE_457       Laptop  Electronics   West
# 999  ORD00999  2023-11-11    ELE_936       Laptop  Electronics  South
#
#             City Customer_ID  Gender  Age  Units_Sold  Unit_Price  Discount  \
# ...
